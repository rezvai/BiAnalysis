# %% [markdown]
# # Презентация решения

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Разработка документации системы
# #### - 1.1 Я сделал документацию, охватывающую все результаты работы по всем модулям.
# #### - 1.2 Документация создана по отраслевому стандарту.

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Разработка документации системы
# #### - 2.1 Созданая презентация охватывает все результаты работы.
# #### - 2.2 Презентация выполнена по отраслевому стандарту.

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Комментарии к коду
# #### - 3.1 Комметарии к коду соотвествуют отраслевому стандарту.
# #### - 3.2 Код прокомментирован по всей системе необходимым комментариями.

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________
