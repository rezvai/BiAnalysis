# %% [markdown]
# # Анализ количественных данных

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Интерактивный дашборд
# #### - 1.1 Я построел график динамики количества вакансий по месяцам.
# #### - 1.2 Все необходимые элементы по заданию присутствуют на дашборде.
# #### - 1.3 Визуализация на дашборде наглядно отражает рост и снижение показателей виджетов.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Поиск зависимостей
# #### - 2.1 Я выявил не менее двух характеристик, проявляющих устойчивые закономерности.
# #### - 2.2 Выполнил описание этих характеристик в файле - Report.html.
# #### - 2.3 Программно выполнил анализ зависимостей между уровнем образования и доходом(пользуясь разработанным дашбордом).

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Фильтрация данных
# #### - 3.1 Я распределил количественные переменные на категории для упрощения анализа.
# #### - 3.2 Все кластеры сопоставил по вакансиям.
# #### - 3.3 Программа, в которой создавался интегрированна с БД, для регулярного обновления информации на дашборде.
# #### - 3.4 Определил и отфильтровал коррелирующие перменные.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 4. Подготовка отчета
# #### - 4.1 Я подгтовил отчет.
# #### - 4.2 Отчет охватывает результаты все сессии.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 5. Проектирование информационно-аналитических систем
# #### - 5.1 Я реализовал методы защиты данных, присутствующих на дашборде.
# #### - 5.2 Сделал возможность доступа к дашборду по ролям пользователя.
# #### - 5.3 Отразил все необходимые эелменты по заданию на дашборде.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________
