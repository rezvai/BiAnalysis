# %% [markdown]
# # Сетевой анализ данных

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Построение графа связей
# #### - 1.1 Я построил граф связей навыков.
# #### - 1.2 Построенный граф позволяет понять, как часто один навык упоминается с другими навыками в вакансии.
# #### - 1.3 Я описал основные метрики полученного графа.

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Подготовка рекомендация
# #### - 2.1 Я подготовил отчет.
# #### - 2.2 Отчет охватывает результаты работы.

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Описание рекомендаций
# #### - 3.1 Я дал рекомендации для образовательных организаций с помощью проведенного анализа.
# #### - 3.2 Я создал визуальный граф в формате .pbix.
# #### - 3.3 В графе присутсвуте возможность интерактивно взаимодействовать с ним.
# #### - 3.4 Я указл основные метрики и описание к ним.

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________________________________________________
