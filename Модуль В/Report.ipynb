# %% [markdown]
# # Обработка и анализ текстовых данных

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Предобработка данных
# #### - 1.1 Я спарсил данные с указанных веб-ресурсов.
# #### - 1.2 Предобработал данные.
# #### - 1.3 Выполнил задание в полном объёме.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Семантический анализ текста
# #### - 2.1 Я произвел анализ связей между словами, сеемантической и синтаксической структуры предложений.
# #### - 2.2 Определил функциональную роль слов.
# #### - 2.3 Выявил эмоциональную окраску слов.
# #### - 2.4 Выполнил анализ региональной специфики востребованных навыков.
# #### - 2.5 Произвел кластерищацию выделенных навыков.
# #### - 2.6 Произвел классификацию выделенных навыков.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Подготовка отчетов
# #### - 3.1 Отчет в работе присутствует.
# #### - 3.2 Сделанный отчет охватывает все результаты сессии.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 4. Визуальный анализ статистики цекстовых признаков
# #### - 4.1 Построил таблицу с классами навыков и частотой встречаемости.
# #### - 4.2 Провел визуальный анализ статистики текстовых признаков.
# #### - 4.3 Определил наиболее востребованные навыки.
# #### - 4.4 Определил наименее востребованные навыки.
# #### - 4.5 Определил наиболее оплачеваемые навыки.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 5. Проектирование информационно=аналитических систем
# #### - 5.1 Я реализовал методы защиты данных, представленных в дашборде.
# #### - 5.2 Выполнен мониторинг данных.
# #### - 5.3 Описал функциональные требования к дашборду.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________
