# %% [markdown]
# # Предобработка количественныз данных

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Загрузка данных
# #### - 1.1 Я собрал данные из открытого источника РосНавык.
# #### - 1.2 Данные содержат записи о вакансиях за последние 3 месяца.
# #### - 1.3 Среди отобранных записей присутствуют поля согласно заданию.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Преобработка данных
# #### - 2.1 Я определил и обосновал наиболее значимые атрибуты в файле Report.ipynb, находящийся в дирректории модуля.
# #### - 2.2 Привел все поля базы к нижнему регистру.
# #### - 2.3 Задал одинаковый формат для каждого поля в базе.
# #### - 2.4 Определил критические пропущенные значения:
#    - В поле Sallary
#    - В поле Skills
# #### В остальных полях пропущенных значений не найдено.
# #### - 2.5 Оценил погрешность пропущенных значений, посчитав соотношение пустых значений к общему количеству:
#    - В поле Sallary: ~79.8%
#    - В поле Skills: ~37.2%

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Описание структуры набора данных
# #### - 3.1 Я предоставил описание для каждого атрибута в файле Report.html.
# #### - 3.2 Я предоставил информацию о кол-ве пропущенных значений для каждого атрибута в файле Report.html.
# #### - 3.3 Я предоставил анализ плотности распределения значений для некоторых атрибутов, отразив часть в файле Report.html.
# #### - 3.4 Я подготовил файл в формате .csv.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 4. Подгтовка отчетов
# #### - 4.1 Я сделал отчет о проделанной работе
# #### - 4.2 Отчет должен охватывать все проделанные мной пункты задания

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 5 Запросы на выборку данных из базы данных
# #### - 5.1 При сборе данных я использовал открытый источник данных РосНавык
# #### - 5.2 Сбор с веб-приложения выполнен программно
# #### - 5.3 Вся предобработка данных выполнена программно(Запросы SQL выгружены в дирректорию модуля)
# #### - 5.4 Написанные запросы к данным не громостки и должны использовать оптимальное кол-во памяти

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________
